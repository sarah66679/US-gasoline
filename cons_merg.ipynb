# %%
# import the library 

from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
from scipy import stats
import seaborn as sns


# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline

plt.style.use('fivethirtyeight')
import warnings
warnings.filterwarnings('ignore')
pd.set_option('display.max_columns', 30)
pd.set_option('display.max_rows', 2000)
from datetime import datetime

# %%
demand=pd.read_csv('csv_monthly_demand.csv')

# %%
export=pd.read_csv('monthly_export_import_supply.csv')

# %%
consumption=pd.read_csv('consumption.csv')
consumption.Date=pd.to_datetime(consumption.Date)
df1=pd.merge(df,consumption,how='inner', on='Date')

# %%
demand.Date=pd.to_datetime(demand.Date)
export.Date=pd.to_datetime(export.Date)
consumption.Date=pd.to_datetime(consumption.Date)

# %%
export.head()
# Out:
#         Date  Motor Gasoline Product Supplied(T/B  per Day)   \
# 0 1973-01-01                                        6117.645
# 1 1973-02-01                                        6436.536
# 2 1973-03-01                                        6512.935
# 3 1973-04-01                                        6541.433
# 4 1973-05-01                                        6907.258
#
#    Finished Motor Gasoline Exports(T/B per Day)  \
# 0                                         1.032
# 1                                         5.071
# 2                                         0.710
# 3                                         4.333
# 4                                         4.871
#
#    Finished Motor Gasoline Imports(T/B per Day)
# 0                                        59.387
# 1                                        95.250
# 2                                        70.742
# 3                                        63.400
# 4                                       101.484

# %%
df=pd.merge(demand,export,how='inner', on='Date')
df1=pd.merge(df,consumption,how='inner', on='Date')

# %%
df1
# Out:
#           Date  U.S. Gasoline Demand (Thousand Barrels per Day)  \
# 0   1993-07-01                                             7788
# 1   1993-08-01                                             7857
# 2   1993-09-01                                             7559
# 3   1993-10-01                                             7553
# 4   1993-11-01                                             7507
# 5   1993-12-01                                             7633
# 6   1994-01-01                                             6931
# 7   1994-02-01                                             7201
# 8   1994-03-01                                             7375
# 9   1994-04-01                                             7447
# 10  1994-05-01                                             7585
# 11  1994-06-01                                             7697
# 12  1994-07-01                                             7720
# 13  1994-08-01                                             7852
# ...

# %%
tabel=pd.read_csv('final_tabel1.csv')

# %%
tabel
# Out:
#             Date  \
# 0     1993-07-16
# 1     1993-07-23
# 2     1993-07-30
# 3     1993-08-06
# 4     1993-08-13
# 5     1993-08-20
# 6     1993-08-27
# 7     1993-09-03
# 8     1993-09-10
# 9     1993-09-17
# 10    1993-09-24
# 11    1993-10-01
# 12    1993-10-08
# 13    1993-10-15
# 14    1993-10-22
# 15    1993-10-29
# 16    1993-11-05
# 17    1993-11-12
# 18    1993-11-19
# 19    1993-11-26
# 20    1993-12-03
# 21    1993-12-10
# 22    1993-12-17
# 23    1994-01-07
# 24    1994-01-14
# 25    1994-01-21
# 26    1994-01-28
# 27    1994-02-04
# 28    1994-02-11
# 29    1994-02-18
# 30    1994-02-25
# 31    1994-03-04
# 32    1994-03-11
# 33    1994-03-18
# 34    1994-03-25
# 35    1994-04-08
# 36    1994-04-15
# 37    1994-04-22
# 38    1994-04-29
# 39    1994-05-06
# 40    1994-05-13
# 41    1994-05-20
# 42    1994-05-27
# 43    1994-06-03
# 44    1994-06-10
# 45    1994-06-17
# 46    1994-06-24
# 47    1994-07-01
# 48    1994-07-08
# 49    1994-07-15
# 50    1994-07-22
# ...

# %%
tabel.index = pd.DatetimeIndex(tabel['Date'])

# %%
tabel= tabel.resample('MS').mean()

# %%
tabel.head()
# Out:
#             Weekly U.S. Ending Stocks of Total Gasoline  (Thousand Barrels)  \
# Date
# 1993-07-01                                      215366.666667
# 1993-08-01                                      205013.000000
# 1993-09-01                                      204009.250000
# 1993-10-01                                      208561.800000
# 1993-11-01                                      212447.750000
#
#             Weekly U.S. Ending Stocks of Finished Motor Gasoline  (Thousand Barrels)  \
# Date
# 1993-07-01                                      177380.333333
# 1993-08-01                                      169446.000000
# 1993-09-01                                      167090.000000
# 1993-10-01                                      171262.000000
# 1993-11-01                                      174098.000000
#
#             U.S. Production of Gasoline (Thousand Barrels per Day)  \
# Date
# 1993-07-01                                        7430.333333
# ...

# %%
tabel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 314 entries, 1993-07-01 to 2019-08-01
# Freq: MS
# Data columns (total 11 columns):
# Weekly U.S. Ending Stocks of Total Gasoline  (Thousand Barrels)                                          314 non-null float64
# Weekly U.S. Ending Stocks of Finished Motor Gasoline  (Thousand Barrels)                                 314 non-null float64
# U.S. Production of Gasoline (Thousand Barrels per Day)                                                   314 non-null float64
# U.S. Gasoline Demand (Thousand Barrels per Day)                                                          314 non-null float64
# Weekly U.S. Imports of Total Gasoline  (Thousand Barrels per Day)                                        314 non-null float64
# Weekly U.S. Imports of Finished Motor Gasoline  (Thousand Barrels per Day)                               314 non-null float64
# ...

# %%
tabel['U.S. Production of Gasoline (Thousand Barrels per Day)']=tabel['U.S. Production of Gasoline (Thousand Barrels per Day)'].astype(int)

# %%
tabel['U.S. Gasoline Demand (Thousand Barrels per Day)']=tabel['U.S. Gasoline Demand (Thousand Barrels per Day)'].astype(int)

# %%
tabel.to_csv('con_month.csv',index=True)

# %%
con=pd.read_csv('cv_con_month.csv')

# %%
con.head()
# Out:
#         Date  \
# 0   7/1/1993
# 1   8/1/1993
# 2   9/1/1993
# 3  10/1/1993
# 4  11/1/1993
#
#    Weekly U.S. Ending Stocks of Finished Motor Gasoline  (Thousand Barrels)  \
# 0                                        177380.3333
# 1                                        169446.0000
# 2                                        167090.0000
# 3                                        171262.0000
# 4                                        174098.0000
#
#    U.S. Production of Gasoline (Thousand Barrels per Day)  \
# 0                                               7430
# 1                                               7288
# 2                                               7528
# 3                                               7416
# 4                                               7652
#
#    U.S. Gasoline Demand (Thousand Barrels per Day)  \
# 0                                             7788
# 1                                             7857
# ...

# %%
con.Date=pd.to_datetime(con.Date)

# %%
con.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 314 entries, 0 to 313
# Data columns (total 9 columns):
# Date                                                                                                     314 non-null datetime64[ns]
# Weekly U.S. Ending Stocks of Finished Motor Gasoline  (Thousand Barrels)                                 314 non-null float64
# U.S. Production of Gasoline (Thousand Barrels per Day)                                                   314 non-null int64
# U.S. Gasoline Demand (Thousand Barrels per Day)                                                          314 non-null int64
# Weekly U.S. Imports of Finished Motor Gasoline  (Thousand Barrels per Day)                               314 non-null float64
# Weekly U.S. All Grades All Formulations Retail Gasoline Prices  (Dollars per Gallon)                     314 non-null float64
# ...

# %%
con['Weekly U.S. Refiner and Blender Net Production of Finished Motor Gasoline  (Thousand Barrels per Day)']=con['Weekly U.S. Refiner and Blender Net Production of Finished Motor Gasoline  (Thousand Barrels per Day)'].astype(int)

# %%
con['Weekly U.S. Ending Stocks of Finished Motor Gasoline  (Thousand Barrels)']=con['Weekly U.S. Ending Stocks of Finished Motor Gasoline  (Thousand Barrels)'].astype(int)

# %%
con['Weekly U.S. Imports of Finished Motor Gasoline  (Thousand Barrels per Day)']=con['Weekly U.S. Imports of Finished Motor Gasoline  (Thousand Barrels per Day)'].astype(int)

# %%
con['Weekly U.S. Refiner and Blender Net Production of Finished Motor Gasoline  (Thousand Barrels per Day)']=con['Weekly U.S. Refiner and Blender Net Production of Finished Motor Gasoline  (Thousand Barrels per Day)'].astype(int)

# %%
con['Weekly U.S. Exports of Finished Motor Gasoline  (Thousand Barrels per Day)']=con['Weekly U.S. Exports of Finished Motor Gasoline  (Thousand Barrels per Day)'].astype(int)

# %%
con.drop('U.S. Production of Gasoline (Thousand Barrels per Day)',axis=1, inplace=True)

# %%
con.head()
# Out:
#         Date  \
# 0 1993-07-01
# 1 1993-08-01
# 2 1993-09-01
# 3 1993-10-01
# 4 1993-11-01
#
#    Weekly U.S. Ending Stocks of Finished Motor Gasoline  (Thousand Barrels)  \
# 0                                             177380
# 1                                             169446
# 2                                             167090
# 3                                             171262
# 4                                             174098
#
#    U.S. Gasoline Demand (Thousand Barrels per Day)  \
# 0                                             7788
# 1                                             7857
# 2                                             7559
# 3                                             7553
# 4                                             7507
#
#    Weekly U.S. Imports of Finished Motor Gasoline  (Thousand Barrels per Day)  \
# 0                                                  0
# 1                                                  0
# ...

# %%
consumption=pd.read_csv('consumption.csv')
consumption.Date=pd.to_datetime(consumption.Date)
con1=pd.merge(con,consumption,how='inner', on='Date')

# %%
con1.head()
# Out:
#         Date  \
# 0 1993-07-01
# 1 1993-08-01
# 2 1993-09-01
# 3 1993-10-01
# 4 1993-11-01
#
#    Weekly U.S. Ending Stocks of Finished Motor Gasoline  (Thousand Barrels)  \
# 0                                             177380
# 1                                             169446
# 2                                             167090
# 3                                             171262
# 4                                             174098
#
#    U.S. Gasoline Demand (Thousand Barrels per Day)  \
# 0                                             7788
# 1                                             7857
# 2                                             7559
# 3                                             7553
# 4                                             7507
#
#    Weekly U.S. Imports of Finished Motor Gasoline  (Thousand Barrels per Day)  \
# 0                                                  0
# 1                                                  0
# ...

# %%
con1.to_csv('final_con.csv',index=False)
